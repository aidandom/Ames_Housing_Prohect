# %% [markdown]
# # Project 2: Ames Housing Project

# %% [markdown]
# **Import libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, train_test_split

pd.set_option('max_columns', 99)

# %% [markdown]
# **Read in data**

# %%
train = pd.read_csv('./datasets/train.csv')

# %%
train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        RRAe        Norm      1Fam      2Story             6             8
# 1        Norm        Norm      1Fam      2Story             7             5
# 2        Norm        Norm      1Fam      1Story             5             7
# 3        Norm        Norm      1Fam      2Story             5             5
# 4        Norm        Norm      1Fam      1.5Fin             6             8
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1976            2005      Gable   CompShg      HdBoard      Plywood
# 1        1996            1997      Gable   CompShg      VinylSd      VinylSd
# 2        1953            2007      Gable   CompShg      VinylSd      VinylSd
# 3        2006            2007      Gable   CompShg      VinylSd      VinylSd
# 4        1900            1993      Gable   CompShg      Wd Sdng      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0      BrkFace         289.0         Gd         TA     CBlock        TA
# 1      BrkFace         132.0         Gd         TA      PConc        Gd
# 2         None           0.0         TA         Gd     CBlock        TA
# 3         None           0.0         TA         TA      PConc        Gd
# 4         None           0.0         TA         TA      PConc        Fa
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            GLQ         533.0            Unf
# 1        TA            No            GLQ         637.0            Unf
# 2        TA            No            GLQ         731.0            Unf
# 3        TA            No            Unf           0.0            Unf
# 4        Gd            No            Unf           0.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        192.0          725.0    GasA         Ex           Y
# 1           0.0        276.0          913.0    GasA         Ex           Y
# 2           0.0        326.0         1057.0    GasA         TA           Y
# 3           0.0        384.0          384.0    GasA         Gd           Y
# 4           0.0        676.0          676.0    GasA         TA           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr         725         754                0         1479
# 1      SBrkr         913        1209                0         2122
# 2      SBrkr        1057           0                0         1057
# 3      SBrkr         744         700                0         1444
# 4      SBrkr         831         614                0         1445
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          2          1              3
# 1             1.0             0.0          2          1              4
# 2             1.0             0.0          1          0              3
# 3             0.0             0.0          2          1              3
# 4             0.0             0.0          2          0              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              8        Typ           1
# 2              1           Gd              5        Typ           0
# 3              1           TA              7        Typ           0
# 4              1           TA              6        Typ           0
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Attchd         1976.0           RFn          2.0
# 1           TA      Attchd         1997.0           RFn          2.0
# 2          NaN      Detchd         1953.0           Unf          1.0
# 3          NaN     BuiltIn         2007.0           Fin          2.0
# 4          NaN      Detchd         1957.0           Unf          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        475.0          TA          TA           Y             0
# 1        559.0          TA          TA           Y             0
# 2        246.0          TA          TA           Y             0
# 3        400.0          TA          TA           Y           100
# 4        484.0          TA          TA           N             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             44               0           0             0          0     NaN
# 1             74               0           0             0          0     NaN
# 2             52               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             59               0           0             0          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 0   NaN          NaN         0        3     2010       WD      130500
# 1   NaN          NaN         0        4     2009       WD      220000
# 2   NaN          NaN         0        1     2010       WD      109000
# 3   NaN          NaN         0        4     2010       WD      174000
# 4   NaN          NaN         0        3     2010       WD      138500

# %%
train.isnull().sum().to_frame().T
# Out:
#    Id  PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  Street  Alley  \
# 0   0    0            0          0           330         0       0   1911
#
#    Lot Shape  Land Contour  Utilities  Lot Config  Land Slope  Neighborhood  \
# 0          0             0          0           0           0             0
#
#    Condition 1  Condition 2  Bldg Type  House Style  Overall Qual  \
# 0            0            0          0            0             0
#
#    Overall Cond  Year Built  Year Remod/Add  Roof Style  Roof Matl  \
# 0             0           0               0           0          0
#
#    Exterior 1st  Exterior 2nd  Mas Vnr Type  Mas Vnr Area  Exter Qual  \
# 0             0             0            22            22           0
#
#    Exter Cond  Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 0           0           0         55         55             58
#
#    BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# 0              55             1              56             1            1
#
#    Total Bsmt SF  Heating  Heating QC  Central Air  Electrical  1st Flr SF  \
# 0              1        0           0            0           0           0
#
#    2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  \
# 0           0                0            0               2               2
#
#    Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  Kitchen Qual  \
# 0          0          0              0              0             0
#
#    TotRms AbvGrd  Functional  Fireplaces  Fireplace Qu  Garage Type  \
# 0              0           0           0          1000          113
#
#    Garage Yr Blt  Garage Finish  Garage Cars  Garage Area  Garage Qual  \
# 0            114            114            1            1          114
#
#    Garage Cond  Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  \
# 0          114            0             0              0               0
#
#    3Ssn Porch  Screen Porch  Pool Area  Pool QC  Fence  Misc Feature  \
# 0           0             0          0     2042   1651          1986
#
#    Misc Val  Mo Sold  Yr Sold  Sale Type  SalePrice
# 0         0        0        0          0          0

# %%
train.dtypes
# Out:
# Id                int64
# PID               int64
# MS SubClass       int64
# MS Zoning        object
# Lot Frontage    float64
#                  ...
# Misc Val          int64
# Mo Sold           int64
# Yr Sold           int64
# Sale Type        object
# SalePrice         int64
# Length: 81, dtype: object

# %%
# see if there are any corrupt columns
train.select_dtypes('O')
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 1           RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2           RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2046        RL   Pave   NaN       IR1          HLS    AllPub     Inside
# 2047        RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# 2048        RL   Pave   NaN       Reg          Bnk    AllPub     Inside
# 2049        RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 2050        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1 Condition 2 Bldg Type House Style  \
# 0           Gtl       Sawyer        RRAe        Norm      1Fam      2Story
# 1           Gtl      SawyerW        Norm        Norm      1Fam      2Story
# 2           Gtl        NAmes        Norm        Norm      1Fam      1Story
# 3           Gtl       Timber        Norm        Norm      1Fam      2Story
# 4           Gtl      SawyerW        Norm        Norm      1Fam      1.5Fin
# ...         ...          ...         ...         ...       ...         ...
# 2046        Gtl       Timber        Norm        Norm      1Fam      1Story
# 2047        Gtl      Edwards        Norm        Norm      1Fam      1Story
# 2048        Gtl      Crawfor        Norm        Norm      1Fam      1.5Fin
# 2049        Gtl        NAmes        Norm        Norm      1Fam      1Story
# 2050        Gtl      Gilbert        Norm        Norm      1Fam      2Story
#
#      Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type Exter Qual  \
# 0         Gable   CompShg      HdBoard      Plywood      BrkFace         Gd
# 1         Gable   CompShg      VinylSd      VinylSd      BrkFace         Gd
# 2         Gable   CompShg      VinylSd      VinylSd         None         TA
# 3         Gable   CompShg      VinylSd      VinylSd         None         TA
# 4         Gable   CompShg      Wd Sdng      Plywood         None         TA
# ...         ...       ...          ...          ...          ...        ...
# 2046      Gable   CompShg      VinylSd      VinylSd         None         Gd
# 2047      Gable   CompShg      VinylSd      VinylSd         None         TA
# 2048      Gable   CompShg      BrkFace        Stone         None         TA
# 2049      Gable   CompShg      Plywood      Plywood         None         TA
# 2050      Gable   CompShg      VinylSd      VinylSd         None         TA
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 0            TA     CBlock        TA        TA            No            GLQ
# 1            TA      PConc        Gd        TA            No            GLQ
# 2            Gd     CBlock        TA        TA            No            GLQ
# 3            TA      PConc        Gd        TA            No            Unf
# 4            TA      PConc        Fa        Gd            No            Unf
# ...         ...        ...       ...       ...           ...            ...
# 2046         TA      PConc        Gd        TA            Av            GLQ
# 2047         TA     CBlock        TA        TA            No            BLQ
# 2048         TA     BrkTil        TA        TA            No            Unf
# 2049         TA     CBlock        TA        TA            No            Rec
# 2050         TA      PConc        TA        TA            No            Unf
#
#      BsmtFin Type 2 Heating Heating QC Central Air Electrical Kitchen Qual  \
# 0               Unf    GasA         Ex           Y      SBrkr           Gd
# 1               Unf    GasA         Ex           Y      SBrkr           Gd
# 2               Unf    GasA         TA           Y      SBrkr           Gd
# 3               Unf    GasA         Gd           Y      SBrkr           TA
# 4               Unf    GasA         TA           Y      SBrkr           TA
# ...             ...     ...        ...         ...        ...          ...
# 2046            Unf    GasA         Ex           Y      SBrkr           Gd
# 2047            Unf    GasA         Ex           Y      SBrkr           TA
# 2048            Unf    GasA         Gd           Y      SBrkr           TA
# 2049            LwQ    GasA         TA           Y      SBrkr           TA
# 2050            Unf    GasA         Gd           Y      SBrkr           Gd
#
#      Functional Fireplace Qu Garage Type Garage Finish Garage Qual  \
# 0           Typ          NaN      Attchd           RFn          TA
# 1           Typ           TA      Attchd           RFn          TA
# 2           Typ          NaN      Detchd           Unf          TA
# 3           Typ          NaN     BuiltIn           Fin          TA
# 4           Typ          NaN      Detchd           Unf          TA
# ...         ...          ...         ...           ...         ...
# 2046        Typ           Gd      Attchd           Fin          TA
# 2047        Typ          NaN      Detchd           Unf          TA
# 2048        Typ           TA      Detchd           Unf          Fa
# 2049        Typ           Gd      Attchd           Unf          TA
# 2050        Typ           TA      Attchd           Fin          TA
#
#      Garage Cond Paved Drive Pool QC Fence Misc Feature Sale Type
# 0             TA           Y     NaN   NaN          NaN       WD
# 1             TA           Y     NaN   NaN          NaN       WD
# 2             TA           Y     NaN   NaN          NaN       WD
# 3             TA           Y     NaN   NaN          NaN       WD
# 4             TA           N     NaN   NaN          NaN       WD
# ...          ...         ...     ...   ...          ...       ...
# 2046          TA           Y     NaN   NaN          NaN       WD
# 2047          TA           Y     NaN   NaN          NaN       WD
# 2048          Fa           Y     NaN   NaN          NaN       WD
# 2049          TA           Y     NaN   NaN          NaN       WD
# 2050          TA           Y     NaN   NaN          NaN       WD
#
# [2051 rows x 42 columns]

# %% [markdown]
# **Data Clean**

# %%
train.corr()['SalePrice'].sort_values().to_frame().T
# Out:
#                 PID  Enclosed Porch  Kitchen AbvGr  Overall Cond  MS SubClass  \
# SalePrice -0.255052       -0.135656      -0.125444     -0.097019    -0.087335
#
#                  Id  Bsmt Half Bath  Low Qual Fin SF   Yr Sold  Misc Val  \
# SalePrice -0.051398       -0.045328        -0.041594 -0.015203 -0.007375
#
#            BsmtFin SF 2  Pool Area   Mo Sold  3Ssn Porch  Screen Porch  \
# SalePrice      0.016255   0.023106  0.032735    0.048732      0.134581
#
#            Bedroom AbvGr  Bsmt Unf SF  2nd Flr SF  Half Bath  Bsmt Full Bath  \
# SalePrice       0.137067      0.19021    0.248452   0.283001        0.283662
#
#            Lot Area  Wood Deck SF  Open Porch SF  Lot Frontage  BsmtFin SF 1  \
# SalePrice  0.296566       0.32649       0.333476      0.341842      0.423519
#
#            Fireplaces  TotRms AbvGrd  Mas Vnr Area  Garage Yr Blt  Full Bath  \
# SalePrice    0.471093       0.504014       0.51223       0.533922   0.537969
#
#            Year Remod/Add  Year Built  1st Flr SF  Total Bsmt SF  Garage Cars  \
# SalePrice         0.55037    0.571849    0.618486       0.628925      0.64822
#
#            Garage Area  Gr Liv Area  Overall Qual  SalePrice
# SalePrice      0.65027     0.697038      0.800207        1.0

# %% [markdown]
# >**High positive corr: Overall Qual, Gr Liv Area, Garage Area, Garage Cars, Total Bsmt SF, 1st Flr SF, Year Built**
#
# >**High negative corr: PID, Enclosed Porch, Kitchen AbvGr**

# %%
# model with highest correlations
df = train.loc[:, ['Overall Qual',
           'Gr Liv Area',
           'Garage Area',
           'Garage Cars',
           'Total Bsmt SF',
           '1st Flr SF',
           'Year Built',
           'PID',
           'Enclosed Porch',
           'Kitchen AbvGr', 
            'SalePrice']]

# %%
# data cleaning
df.dtypes
# Out:
# Overall Qual        int64
# Gr Liv Area         int64
# Garage Area       float64
# Garage Cars       float64
# Total Bsmt SF     float64
# 1st Flr SF          int64
# Year Built          int64
# Enclosed Porch      int64
# Kitchen AbvGr       int64
# SalePrice           int64
# dtype: object

# %%
df.shape
# Out:
# (2051, 10)

# %%
df.isnull().sum()
# Out:
# Overall Qual      0
# Gr Liv Area       0
# Garage Area       1
# Garage Cars       1
# Total Bsmt SF     1
# 1st Flr SF        0
# Year Built        0
# Enclosed Porch    0
# Kitchen AbvGr     0
# SalePrice         0
# dtype: int64

# %%
# only 2 rows with missing values -- drop
df = df.dropna()

# %%
df.shape
# Out:
# (2049, 10)

# %%
X = df.drop(columns=['SalePrice'])
y = df['SalePrice']

# %%
lr = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# r2 scores for model
print('Training score:', lr.score(X_train, y_train))
print('Test score:', lr.score(X_test, y_test))
# Out:
# Training score: 0.7787399858947955
# Test score: 0.8242690264643936

# %%
cross_val_score(lr, X_train, y_train, cv=5).mean()
# Out:
# 0.7597236735763854

# %%
cross_val_score(lr, X, y, cv=5).mean()
# Out:
# 0.7861120970881308

# %%
lr.coef_
# Out:
# array([ 2.04236125e+04,  4.77244546e+01,  2.55469336e+01,  7.39534825e+03,
#         1.09002326e+01,  1.87222979e+01,  3.56441952e+02,  3.95141712e+00,
#        -2.55093765e+04])

# %%
df.columns
# Out:
# Index(['Overall Qual', 'Gr Liv Area', 'Garage Area', 'Garage Cars',
#        'Total Bsmt SF', '1st Flr SF', 'Year Built', 'Enclosed Porch',
#        'Kitchen AbvGr', 'SalePrice'],
#       dtype='object')

# %%
lr.intercept_
# Out:
# -749732.5691271601

# %% [markdown]
# >So far model has a pretty balanced bias and variance.

# %%
pred = lr.predict(X)

# %%
plt.figure(figsize=(8,6))

plt.scatter(pred, y)

plt.title('Predicted Price vs Actual Price', fontsize=20)
plt.xlabel('Predicted Price')
plt.ylabel('Actual Price')
# Out:
# Text(0, 0.5, 'Actual Price')

# %% [markdown]
# ## Investigate Outliers

# %%
np.where((pred >= 200_000) & (pred <= 300_000))
# Out:
# (array([   1,    5,   11,   13,   14,   19,   21,   22,   32,   34,   37,
#           45,   49,   52,   60,   61,   62,   67,   69,   70,   71,   73,
#           74,   85,   86,   91,   92,   95,   98,  102,  104,  107,  109,
#          115,  117,  126,  133,  137,  141,  144,  146,  148,  153,  156,
#          161,  163,  172,  174,  175,  178,  184,  185,  187,  188,  191,
#          192,  193,  194,  195,  196,  202,  206,  208,  211,  212,  215,
#          229,  231,  236,  237,  243,  245,  246,  250,  253,  254,  257,
#          265,  268,  277,  283,  288,  289,  292,  299,  300,  309,  310,
#          311,  313,  316,  318,  319,  321,  322,  335,  338,  339,  344,
#          348,  364,  369,  378,  384,  385,  387,  414,  415,  422,  428,
#          429,  431,  434,  440,  447,  448,  451,  458,  461,  463,  468,
#          469,  471,  473,  475,  479,  482,  483,  492,  502,  504,  506,
#          511,  512,  515,  516,  522,  531,  532,  536,  538,  540,  541,
#          543,  545,  552,  558,  563,  567,  568,  571,  578,  582,  589,
#          591,  594,  595,  596,  597,  598,  600,  601,  606,  607,  608,
#          609,  613,  615,  618,  620,  626,  627,  630,  631,  632,  637,
#          639,  640,  641,  645,  646,  647,  648,  661,  664,  668,  669,
#          673,  676,  681,  693,  694,  699,  706,  707,  710,  720,  725,
#          727,  728,  729,  734,  739,  747,  750,  752,  753,  756,  761,
#          762,  765,  770,  771,  778,  779,  780,  788,  789,  792,  793,
#          795,  798,  799,  801,  808,  809,  812,  818,  825,  832,  837,
#          838,  839,  844,  845,  846,  847,  849,  851,  852,  856,  858,
#          860,  862,  863,  864,  865,  866,  867,  872,  879,  880,  884,
#          887,  888,  889,  890,  895,  897,  899,  902,  905,  907,  913,
#          914,  915,  916,  920,  921,  922,  927,  935,  936,  939,  941,
#          944,  946,  947,  949,  953,  956,  958,  968,  969,  971,  974,
#          976,  977,  979,  980,  985,  988,  989,  990,  992,  993,  994,
#         1003, 1006, 1014, 1016, 1018, 1024, 1025, 1033, 1036, 1038, 1044,
#         1056, 1059, 1061, 1063, 1066, 1069, 1070, 1072, 1085, 1087, 1090,
#         1092, 1099, 1103, 1104, 1108, 1110, 1113, 1115, 1122, 1123, 1126,
#         1129, 1131, 1132, 1133, 1134, 1136, 1139, 1140, 1142, 1143, 1147,
#         1149, 1150, 1153, 1160, 1161, 1168, 1175, 1177, 1179, 1186, 1187,
#         1188, 1198, 1199, 1201, 1202, 1206, 1207, 1209, 1214, 1218, 1219,
#         1221, 1223, 1230, 1231, 1232, 1233, 1236, 1237, 1238, 1240, 1241,
#         1242, 1244, 1248, 1249, 1250, 1254, 1255, 1257, 1261, 1264, 1266,
#         1269, 1271, 1272, 1275, 1276, 1278, 1280, 1281, 1283, 1284, 1285,
#         1286, 1291, 1296, 1298, 1299, 1300, 1303, 1305, 1308, 1311, 1313,
#         1314, 1318, 1324, 1326, 1328, 1333, 1334, 1336, 1337, 1341, 1346,
#         1349, 1350, 1353, 1357, 1359, 1363, 1367, 1381, 1392, 1396, 1398,
#         1400, 1403, 1408, 1409, 1411, 1412, 1413, 1419, 1420, 1423, 1424,
#         1425, 1429, 1432, 1433, 1435, 1436, 1437, 1448, 1454, 1458, 1459,
#         1473, 1476, 1479, 1481, 1493, 1496, 1501, 1503, 1511, 1516, 1521,
#         1522, 1524, 1532, 1536, 1542, 1545, 1546, 1554, 1555, 1556, 1558,
#         1559, 1562, 1564, 1565, 1566, 1571, 1572, 1573, 1580, 1581, 1582,
#         1585, 1586, 1587, 1597, 1600, 1601, 1602, 1603, 1604, 1607, 1609,
#         1611, 1612, 1616, 1617, 1620, 1624, 1626, 1628, 1632, 1635, 1640,
#         1643, 1650, 1651, 1655, 1661, 1667, 1669, 1672, 1673, 1686, 1687,
#         1689, 1694, 1695, 1698, 1700, 1702, 1703, 1707, 1713, 1717, 1719,
#         1722, 1725, 1727, 1733, 1737, 1739, 1743, 1744, 1745, 1746, 1756,
#         1757, 1761, 1762, 1764, 1766, 1771, 1773, 1778, 1779, 1784, 1785,
#         1788, 1789, 1790, 1793, 1798, 1800, 1804, 1805, 1810, 1811, 1813,
#         1814, 1819, 1822, 1823, 1826, 1827, 1829, 1830, 1834, 1837, 1838,
#         1841, 1848, 1849, 1851, 1852, 1853, 1856, 1861, 1869, 1870, 1874,
#         1879, 1880, 1884, 1894, 1899, 1901, 1906, 1908, 1915, 1922, 1924,
#         1929, 1933, 1936, 1937, 1939, 1942, 1945, 1946, 1947, 1949, 1951,
#         1953, 1954, 1955, 1958, 1960, 1961, 1963, 1965, 1971, 1974, 1976,
#         1977, 1982, 1983, 1984, 1988, 1992, 1995, 1996, 1999, 2000, 2010,
#         2011, 2013, 2019, 2020, 2021, 2022, 2023, 2026, 2031, 2032, 2034,
#         2038, 2043, 2044, 2048]),)

# %%
X.iloc[1,:].to_frame().T
# Out:
#    Overall Qual  Gr Liv Area  Garage Area  Garage Cars  Total Bsmt SF  \
# 1           7.0       2122.0        559.0          2.0          913.0
#
#    1st Flr SF  Year Built          PID  Enclosed Porch  Kitchen AbvGr
# 1       913.0      1996.0  531379050.0             0.0            1.0

# %%
# find index of outliers
np.where(pred > 500_000) # https://thispointer.com/find-the-index-of-a-value-in-numpy-array/
# Out:
# (array([ 960, 1883]),)

# %%
X.iloc[960, :].to_frame().T
# Out:
#      Overall Qual  Gr Liv Area  Garage Area  Garage Cars  Total Bsmt SF  \
# 960          10.0       5642.0       1418.0          2.0         6110.0
#
#      1st Flr SF  Year Built          PID  Enclosed Porch  Kitchen AbvGr
# 960      4692.0      2008.0  908154235.0             0.0            1.0

# %%
X.iloc[1883, :].to_frame().T
# Out:
#       Overall Qual  Gr Liv Area  Garage Area  Garage Cars  Total Bsmt SF  \
# 1885          10.0       5095.0       1154.0          3.0         5095.0
#
#       1st Flr SF  Year Built          PID  Enclosed Porch  Kitchen AbvGr
# 1885      5095.0      2008.0  908154195.0             0.0            1.0

# %% [markdown]
# ## Kitchen AbvGr values?

# %%
X['Kitchen AbvGr'].value_counts()
# Out:
# 1    1958
# 2      88
# 0       2
# 3       1
# Name: Kitchen AbvGr, dtype: int64

# %% [markdown]
# # Modeling

# %%
from sklearn.linear_model import RidgeCV, LassoCV, ElasticNetCV
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
Z_train = ss.fit_transform(X_train)
Z_test = ss.transform(X_test)

alpha = np.logspace(0, 3, 100)

# LASSO
lasso_cv = LassoCV(alphas=alpha, cv=5)
lasso_cv.fit(Z_train, y_train);

# Ridge
ridge_cv = RidgeCV(cv=5)
ridge_cv.fit(Z_train, y_train)

# Elastic Net
elastic_net_cv = ElasticNetCV(alphas=alpha, cv=5)
elastic_net_cv.fit(Z_train, y_train);

# %%
lasso_cv.alpha_
# Out:
# 533.6699231206312

# %%
print('OLS')
print(lr.score(X_train, y_train))
print(lr.score(X_test, y_test), '\n')

print('LASSO')
print(lasso_cv.score(Z_train, y_train))
print(lasso_cv.score(Z_test, y_test), '\n')

print('Ridge')
print(ridge_cv.score(Z_train, y_train))
print(ridge_cv.score(Z_test, y_test), '\n')

print('Elastic Net')
print(elastic_net_cv.score(Z_train, y_train))
print(elastic_net_cv.score(Z_test, y_test))
# Out:
# OLS
# 0.778855742136836
# 0.8247086340204753
#
# LASSO
# 0.7787040686145948
# 0.8232274640775339
#
# Ridge
# 0.7788460676864989
# 0.8247849678863757
#
# Elastic Net
# 0.7578121772731806
# 0.8017715518646152

# %% [markdown]
# >**Lasso and Ridge are comparable, but I chose Lasso to help with feature selection**

# %%
pd.DataFrame(lasso_cv.coef_, index=X.columns)
# Out:
#                            0
# Overall Qual    29397.521470
# Gr Liv Area     23688.133171
# Garage Area      5617.903409
# Garage Cars      5409.724723
# Total Bsmt SF    4908.690590
# 1st Flr SF       7342.009698
# Year Built      10310.945611
# PID              -554.377588
# Enclosed Porch      0.000000
# Kitchen AbvGr   -4467.581675

# %% [markdown]
# > **Enclosed Porch feature not needed**

# %% [markdown]
# **Exploring Interaction terms with PolynomialFeatures**

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(include_bias=False)
X_train_pf = pf.fit_transform(X_train)
X_test_pf = pf.transform(X_test)

lr_pf = LinearRegression()
lr_pf.fit(X_train_pf, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
import warnings
warnings.filterwarnings('ignore')

ss = StandardScaler()
Z_train_pf = ss.fit_transform(X_train_pf)
Z_test_pf = ss.transform(X_test_pf)

alpha = np.logspace(0, 3, 100)

# LASSO
lasso_cv_pf = LassoCV(alphas=alpha, cv=5)
lasso_cv_pf.fit(Z_train_pf, y_train);

# Ridge
ridge_cv_pf = RidgeCV(cv=5)
ridge_cv_pf.fit(Z_train_pf, y_train)

# Elastic Net
elastic_net_cv_pf = ElasticNetCV(alphas=alpha, cv=5)
elastic_net_cv_pf.fit(Z_train_pf, y_train);

# %%
print('OLS poly')
print(lr_pf.score(X_train_pf, y_train))
print(lr_pf.score(X_test_pf, y_test), '\n')

print('LASSO poly')
print(lasso_cv_pf.score(Z_train_pf, y_train))
print(lasso_cv_pf.score(Z_test_pf, y_test), '\n')

print('Ridge poly')
print(ridge_cv_pf.score(Z_train_pf, y_train))
print(ridge_cv_pf.score(Z_test_pf, y_test), '\n')

print('Elastic Net pol')
print(elastic_net_cv_pf.score(Z_train_pf, y_train))
print(elastic_net_cv_pf.score(Z_test_pf, y_test))
# Out:
# OLS poly
# 0.761122842256202
# 0.7690813767320033
#
# LASSO poly
# 0.8685427552297467
# 0.8742386826601745
#
# Ridge poly
# 0.8709132696100765
# 0.8762503177579273
#
# Elastic Net pol
# 0.8223037195431744
# 0.8467047502954984

# %% [markdown]
# **r2 scores are higher and more balanced after Regularization**
#
# >Relatively high training r2 score for LASSO and Ridge indicate a low bias. About 87% of variance in the data is explained by the new regularized model.
#
# >Relatively high test r2 score for LASSO and Ridge, as well. Nearly equal training and testing r2 scores incidate low variance in the new regularized mode.

# %%
lasso_cv_betas = pd.Series(index = pf.get_feature_names(X.columns), data = lasso_cv_pf.coef_)
lasso_cv_betas[lasso_cv_betas != 0]
# Out:
# Overall Qual                   -13818.964425
# Garage Cars                     -6432.601062
# 1st Flr SF                       1247.374577
# Year Built                      10494.789947
# Overall Qual Gr Liv Area        41177.427731
# Overall Qual Garage Area         7988.279092
# Overall Qual Total Bsmt SF      45534.662917
# Overall Qual 1st Flr SF         13379.820134
# Overall Qual Kitchen AbvGr      -3510.988078
# Gr Liv Area Garage Cars          7130.365066
# Gr Liv Area 1st Flr SF          -9958.843066
# Gr Liv Area Year Built           4206.477351
# Gr Liv Area PID                 -1232.885392
# Garage Area^2                     705.473892
# Garage Area PID                  -994.109713
# Garage Area Enclosed Porch       -433.366421
# Garage Cars Total Bsmt SF       18128.783395
# Garage Cars 1st Flr SF           3194.930559
# Garage Cars Enclosed Porch       -609.232248
# Garage Cars Kitchen AbvGr       -5649.652523
# Total Bsmt SF^2                -23890.145311
# Total Bsmt SF 1st Flr SF       -31125.123300
# Total Bsmt SF PID                -841.050806
# Total Bsmt SF Enclosed Porch     1938.385549
# 1st Flr SF^2                     -953.865924
# 1st Flr SF Year Built            9903.389053
# Year Built PID                   2075.898792
# dtype: float64

# %% [markdown]
# > **All relevant features and interaction terms from model**
